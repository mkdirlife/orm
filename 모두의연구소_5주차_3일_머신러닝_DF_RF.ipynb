# %% [markdown]
# <a href="https://colab.research.google.com/github/mkdirlife/orm/blob/main/%EB%AA%A8%EB%91%90%EC%9D%98%EC%97%B0%EA%B5%AC%EC%86%8C_5%EC%A3%BC%EC%B0%A8_3%EC%9D%BC_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_DF_RF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 모델

# %%
## 기본 패키지 모음
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

## 전처리 및 모델링 준비를 위한 패키지
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

## 실제 모델링을 위한 패키지
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn import tree
from sklearn.ensemble import RandomForestClassifier


## 모델 평가를 위한 패키지
from sklearn.metrics import classification_report
from sklearn import metrics

# %%
# 1. data import
# 다운받은 데이터를 코랩에서 불러오겠습니다.
wine = pd.read_csv('/content/winequality_red.csv')
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
# 2. 데이터 확인
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
# 2. 데이터 확인 - 결측치가 없네요^^
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# 2. 데이터 확인
# 타겟 -> 우리가 예측해야 하는 변수
wine['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
# 2. 데이터 확인
sns.countplot(x='quality', data=wine)

# 특성별도 데이터를 시각화 하여 데이터에 대한 정보를 파악합니다
df1 = wine.select_dtypes([int, float])

for i, col in enumerate(df1.columns):
    plt.figure(i)
    sns.barplot(x='quality', y =col, data=df1)

# %%
# 분류 -> 좋으냐 나쁘냐 이렇게 하는 방법(이게 더 쉽다)
# 회귀 -> 집값 처럼 연속적인값 0원~1억원 -> 이중에서 얼마든지 예측
# 회귀에서 분류로 바꿀 수 있음. 0원~5천만원 -> 집값이 낮다. / 5천만원~1억원 집값 높다 -> 분류

# %%
## 6.5점을 기준으로 좋은 와인과 나쁜 와인을 구분하겠다고 선언
bins = (2, 6.5, 8)
group_names = ['bad', 'good']
wine['quality'] = pd.cut(wine['quality'], bins = bins, labels = group_names)

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol quality
# 0         9.4     bad
# 1         9.8     bad
# 2         9.8     bad
# 3         9.8     bad
# 4         9.4     bad
# ...       ...     ...
# 1594     10.5     bad
# 1595     11.2     bad
# 1596     11.0     bad
# 1597     10.2     bad
# 1598     11.0     bad
#
# [1599 rows x 12 columns]

# %%
## Good/Bad는 인식할 수 없음. 따라서 이를 인식할 수 있도록 Label Encoding을 실시

label_quality = LabelEncoder()
wine['quality'] = label_quality.fit_transform(wine['quality'])

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        0
# 1         9.8        0
# 2         9.8        0
# 3         9.8        0
# 4         9.4        0
# ...       ...      ...
# 1594     10.5        0
# 1595     11.2        0
# 1596     11.0        0
# 1597     10.2        0
# 1598     11.0        0
#
# [1599 rows x 12 columns]

# %%
##종속변수와 독립변수를 나누어주는 작업
x = wine.drop('quality', axis = 1)
y = wine['quality']

## 변수별로 Train과 Test 쓸 데이터 셋을 분류x
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)


## 측정 지표의 표준화.
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)
# 머신러닝은 숫자가 퍼져있거나 넓을수록 예측을 잘 못하는 경향이 있어서 표준화를 많이 사용한다.
# 컴퓨터 성능에 따라서 결과 나오는 속도가 많이 차이남.

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
x_train
# Out:
# array([[ 0.21833164,  0.88971201,  0.19209222, ...,  1.09349989,
#          0.45822284,  1.12317723],
#        [-1.29016623, -1.78878251,  0.65275338, ..., -0.40043872,
#         -0.40119696,  1.40827174],
#        [ 1.49475291, -0.78434707,  1.01104539, ..., -0.07566946,
#          0.51551749, -0.58738978],
#        ...,
#        [-0.65195559,  0.49909822, -1.08752211, ...,  1.28836145,
#         -0.68767023, -0.87248428],
#        [-0.24582155, -1.84458448,  0.39683051, ...,  0.05423824,
#          0.80199076,  1.40827174],
#        [-1.46422367, -1.34236676, -0.06383064, ...,  0.50891521,
#         -0.68767023,  2.92877575]])

# %%
## 로지스틱 회귀
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred))
print("Recall:", metrics.recall_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       273
#            1       0.71      0.26      0.37        47
#
#     accuracy                           0.88       320
#    macro avg       0.80      0.62      0.65       320
# weighted avg       0.86      0.88      0.85       320
#
# Accuracy: 0.875
# Precision: 0.7058823529411765
# Recall: 0.2553191489361702

# %%
## SVC
model_svc = SVC()
model_svc.fit(x_train, y_train)
y_pred_svc = model_svc.predict(x_test)
print(classification_report(y_test, y_pred_svc))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred_svc))
print("Precision:", metrics.precision_score(y_test, y_pred_svc))
print("Recall:", metrics.recall_score(y_test, y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       273
#            1       0.71      0.26      0.37        47
#
#     accuracy                           0.88       320
#    macro avg       0.80      0.62      0.65       320
# weighted avg       0.86      0.88      0.85       320
#
# Accuracy: 0.875
# Precision: 0.7058823529411765
# Recall: 0.2553191489361702

# %%
## KNN
model_knn = KNeighborsClassifier(5)
model_knn.fit(x_train, y_train)
y_pred_knn = model_knn.predict(x_test)
print(classification_report(y_test, y_pred_knn))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred_knn))
print("Precision:", metrics.precision_score(y_test, y_pred_knn))
print("Recall:", metrics.recall_score(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       273
#            1       0.61      0.40      0.49        47
#
#     accuracy                           0.88       320
#    macro avg       0.76      0.68      0.71       320
# weighted avg       0.86      0.88      0.86       320
#
# Accuracy: 0.875
# Precision: 0.6129032258064516
# Recall: 0.40425531914893614

# %%
## NB
model_NB = GaussianNB()
model_NB.fit(x_train, y_train)
y_pred_NB = model_NB.predict(x_test)
print(classification_report(y_test, y_pred_NB))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred_NB))
print("Precision:", metrics.precision_score(y_test, y_pred_NB))
print("Recall:", metrics.recall_score(y_test, y_pred_NB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91       273
#            1       0.50      0.74      0.60        47
#
#     accuracy                           0.85       320
#    macro avg       0.73      0.81      0.75       320
# weighted avg       0.89      0.85      0.86       320
#
# Accuracy: 0.853125
# Precision: 0.5
# Recall: 0.7446808510638298

# %%
## Decision Tree
model_tree = tree.DecisionTreeClassifier()
model_tree.fit(x_train, y_train)
y_pred_tree = model_tree.predict(x_test)
print(classification_report(y_test, y_pred_tree))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred_tree))
print("Precision:", metrics.precision_score(y_test, y_pred_tree))
print("Recall:", metrics.recall_score(y_test, y_pred_tree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       273
#            1       0.45      0.45      0.45        47
#
#     accuracy                           0.84       320
#    macro avg       0.68      0.68      0.68       320
# weighted avg       0.84      0.84      0.84       320
#
# Accuracy: 0.8375
# Precision: 0.44680851063829785
# Recall: 0.44680851063829785

# %%
## RandomForest
model_rfc = RandomForestClassifier(n_estimators=200)
model_rfc.fit(x_train, y_train)
y_pred_rfc = model_rfc.predict(x_test)
print(classification_report(y_test, y_pred_rfc))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred_rfc))
print("Precision:", metrics.precision_score(y_test, y_pred_rfc))
print("Recall:", metrics.recall_score(y_test, y_pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       273
#            1       0.67      0.43      0.52        47
#
#     accuracy                           0.88       320
#    macro avg       0.79      0.69      0.73       320
# weighted avg       0.87      0.88      0.87       320
#
# Accuracy: 0.884375
# Precision: 0.6666666666666666
# Recall: 0.425531914893617

# %%
print("Logistic Regression Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Support Vector Machine Accuracy:", metrics.accuracy_score(y_test, y_pred_svc))
print("KNN Accuracy:", metrics.accuracy_score(y_test, y_pred_knn))
print("Gausian NB Accuracy:", metrics.accuracy_score(y_test, y_pred_NB))
print("Decision Tree Accuracy:", metrics.accuracy_score(y_test, y_pred_NB))
print("Random Forest Accuracy:", metrics.accuracy_score(y_test, y_pred_rfc))

acc_df = pd.DataFrame({'classifier':
                      ['Logistic Regression ',
                       'Support Vector Machine',
                       'KNN',
                       'Gausian NB',
                       'Decision Tree',
                       'Random Forest'],
                      'accuracy':
                      [metrics.accuracy_score(y_test, y_pred),
                       metrics.accuracy_score(y_test, y_pred_svc),
                       metrics.accuracy_score(y_test, y_pred_knn),
                       metrics.accuracy_score(y_test, y_pred_NB),
                       metrics.accuracy_score(y_test, y_pred_tree),
                       metrics.accuracy_score(y_test, y_pred_rfc),
                       ]
                      })

acc_df
# Out:
# Logistic Regression Accuracy: 0.875
# Support Vector Machine Accuracy: 0.875
# KNN Accuracy: 0.875
# Gausian NB Accuracy: 0.853125
# Decision Tree Accuracy: 0.853125
# Random Forest Accuracy: 0.884375
#                classifier  accuracy
# 0    Logistic Regression   0.875000
# 1  Support Vector Machine  0.875000
# 2                     KNN  0.875000
# 3              Gausian NB  0.853125
# 4           Decision Tree  0.837500
# 5           Random Forest  0.884375

# %%
##종속변수와 독립변수를 나누어주는 작업
x = wine.drop('quality', axis = 1)
y = wine['quality']

## 변수별로 Train과 Test 쓸 데이터 셋을 분류x
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state = 2023)
dt.fit(x_train, y_train)
print(dt.score(x_train, y_train))
print(dt.score(x_test, y_test))
# Out:
# 1.0
# 0.9

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize =(10,7))
plot_tree(dt)
plt.show()

# %%
# 1번(맨위)
# sample 1279 - 품질이 나쁜 와인(6.5 이하) 1109 / 품질이 좋은 와인(6.5 이상) 170

# %%
plt.figure(figsize =(10,7))
plot_tree(dt, max_depth = 1, filled = True)
plt.show()

# %%
# | 구분 | 음성 클래스(0)
# → 6.5이하인 나쁜와인 | 양성 클래스(1)
# → 6.5점 이상 좋은 와인 |
# | --- | --- | --- |
# | 전체 | 1,279 | 1,279 |
# | 클래스 갯수 | 1,109 | 170 |
# | 클래스/전체 | 86.7% | 13.3% |  1109/1279    170/1279
# | 제곱 | 75.2% | 1.8% |            제곱        77 = 75.2 + 1.8
# | 지니계수 | 23.0% → 0.23 |  |   0 이면 완전하게 분리되는 지수
# 지니 불순도가 0.5 → 50%면 가장 안좋은 케이스이며, 지니 계수가 0에 가까울수록 좋은 케이스입니다.
# 0.5 이상이 나오는 경우는 데이터가 이상해서 나오는 경우가 있음. 어쨌든 안 좋은 케이스임

# %%
# 검증 방법
# 1. 각 트리별로 조건을 데이터에 녹여서 그 조건에 해당하는 데이터가 실제로 예측을 잘했는지 살펴본다.(직접적인 데이터 확인)
# 2. 성능! 비교해서 과적합나지 않았는지 성능이 너무 낮지 않은지 확인.

# %% [markdown]
# # 랜덤포레스트

# %%
# 1. 랜덤포레스트는 각 트리를 훈련하기 위한 데이터를 랜덤하게 만듬.
# 굉장히 다양한 경우의 수로 학습을 할 수 있다.
# 1번째의 500개의 데이터, 2번째의 500개의 데이터, 3번째의 500개의 데이터는 같을수도 다를수도 있다.
# 결론적으로는 같을 확률이 거의 없어서 모두 다른 의사결정나무 3개가 생성되게 된다.
# 중복추출이 가능 이를 붓스트랩 방법이라고 한다.
# 데이터 1000개가 있으면 중복추출을 하기 때문에 훈련세트 크기와 같게 만든다.
# 1번째 특징 중복추출로 train dataset과 동일하게 추출한다.

# 랜덤포레스트는 기본적으로 전체특성(X변수) 개수의 제곱근(루트)만큼 특성(변수)를 정하게 됩니다.
# 2. 변수가 9개면 3개를 선택한다고 보면 된다.

# 1. 데이터도 랜덤하게
# 2. 변수도 랜덤하게

# 맞짱
# 짱1명 - 일반학생1명
# 앙상블
# 짱1명 - 일반학생100명
